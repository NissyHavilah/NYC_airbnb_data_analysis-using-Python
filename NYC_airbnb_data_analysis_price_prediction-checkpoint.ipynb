# %% [markdown]
# ## 1. Importing neccessary libraries & reading the dataset

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import statistics
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# reading the dataset
df = pd.read_csv("AB_NYC_2019.csv")
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# checking for the shape of the dataset
df.shape
# Out:
# (48895, 16)

# %%
# checking for datatype of each column in the dataset
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
# checking for summary of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# checking for the count of unique values in each column
df.nunique()
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
# checking null value count for each column
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ## 2. dropping unnecessary columns

# %%
df.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %%
# dropping unnecessary columns
df.drop(['id', 'name', 'host_name'], axis=1, inplace=True)

# %% [markdown]
# ## 3. working on datatypes

# %%
df.head(2)
# Out:
#    host_id neighbourhood_group neighbourhood  latitude  longitude  \
# 0     2787            Brooklyn    Kensington  40.64749  -73.97237
# 1     2845           Manhattan       Midtown  40.75362  -73.98377
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355

# %%
# checking for datatype of each column in the dataset
df.dtypes
# Out:
# host_id                             int64
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
# changing type of this column to datetime
df['last_review']= pd.to_datetime(df['last_review'])

# %% [markdown]
# ## 4. working on missing values

# %%
# checking null value count for each column
df.isnull().sum()
# Out:
# host_id                               0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# fill null values with max value of the column
df['last_review'].fillna(max(df.last_review), inplace=True)

# %%
# fill null values with mean(average) value of the column
mean = df['reviews_per_month'].mean()
df['reviews_per_month'].fillna(mean, inplace=True)

# %%
# checking null value count for each column
df.isnull().sum()
# Out:
# host_id                           0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# ## 5. renaming columns

# %%
df.head(2)
# Out:
#    host_id neighbourhood_group neighbourhood  latitude  longitude  \
# 0     2787            Brooklyn    Kensington  40.64749  -73.97237
# 1     2845           Manhattan       Midtown  40.75362  -73.98377
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355

# %%
# checking count of unique value
df['neighbourhood_group'].value_counts()
# Out:
# neighbourhood_group
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: count, dtype: int64

# %%
# renaming multiple columns
df.rename(columns={'neighbourhood_group': 'borough', 'calculated_host_listings_count': 'host_listings_count', 'price': 'price_in_dollars'}, inplace=True)

# %%
df.head(2)
# Out:
#    host_id    borough neighbourhood  latitude  longitude        room_type  \
# 0     2787   Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1     2845  Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price_in_dollars  minimum_nights  number_of_reviews last_review  \
# 0               149               1                  9  2018-10-19
# 1               225               1                 45  2019-05-21
#
#    reviews_per_month  host_listings_count  availability_365
# 0               0.21                    6               365
# 1               0.38                    2               355

# %% [markdown]
# ## 6. changing data type

# %%
df['reviews_per_month'] = df['reviews_per_month'].astype(int)

# %% [markdown]
# ## 7. checking categorical fields data quality

# %%
# checking count of unique value
df['borough'].value_counts()
# Out:
# borough
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: count, dtype: int64

# %%
# checking count of unique value
df['neighbourhood'].value_counts()
# Out:
# neighbourhood
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
#                       ...
# Fort Wadsworth           1
# Richmondtown             1
# New Dorp                 1
# Rossville                1
# Willowbrook              1
# Name: count, Length: 221, dtype: int64

# %%
# checking count of unique value
df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#    host_id    borough neighbourhood  latitude  longitude        room_type  \
# 0     2787   Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1     2845  Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price_in_dollars  minimum_nights  number_of_reviews last_review  \
# 0               149               1                  9  2018-10-19
# 1               225               1                 45  2019-05-21
#
#    reviews_per_month  host_listings_count  availability_365
# 0                  0                    6               365
# 1                  0                    2               355

# %% [markdown]
# ## 8. EDA & Visualizations

# %%
# setting default plot size
sns.set(rc={'figure.figsize':(8,6)})

# %% [markdown]
# ## a. Top 10 host with max listings

# %%
max_host_listings = df.groupby(['host_id'])['host_listings_count'].count().sort_values(ascending=False)
max_host_listings.head(10)
# Out:
# host_id
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 16098958      96
# 12243051      96
# 61391963      91
# 22541573      87
# 200380610     65
# 1475015       52
# Name: host_listings_count, dtype: int64

# %%
max_host_listings_df = pd.DataFrame(max_host_listings.head(10))
max_host_listings_df.reset_index(inplace = True)
max_host_listings_df
# Out:
#      host_id  host_listings_count
# 0  219517861                  327
# 1  107434423                  232
# 2   30283594                  121
# 3  137358866                  103
# 4   16098958                   96
# 5   12243051                   96
# 6   61391963                   91
# 7   22541573                   87
# 8  200380610                   65
# 9    1475015                   52

# %%
fig = sns.barplot(x = "host_id", y = "host_listings_count", data = max_host_listings_df, palette = "viridis")
plt.xlabel("Host id's")
plt.ylabel("Count of listings")
plt.title("Hosts with the most listings in New York")
fig.set_xticklabels(fig.get_xticklabels(), rotation=45)
plt.show(fig)

# %% [markdown]
# ## b. Average price based on room-type

# %%
avg_price_room_type = df.groupby(['room_type'])['price_in_dollars'].agg('mean').sort_values(ascending=False)
avg_price_room_type
# Out:
# room_type
# Entire home/apt    211.794246
# Private room        89.780973
# Shared room         70.127586
# Name: price_in_dollars, dtype: float64

# %%
avg_price_room_type_df = pd.DataFrame(avg_price_room_type)
avg_price_room_type_df
# Out:
#                  price_in_dollars
# room_type
# Entire home/apt        211.794246
# Private room            89.780973
# Shared room             70.127586

# %%
labels = ['Entire home/apt', 'Private room', 'Shared room']
explode = (.1,0,.2)

# %%
plt.figure(figsize=(8, 6))
plt.pie(avg_price_room_type_df['price_in_dollars'], labels=labels, explode = explode, autopct='%1.1f%%', colors=sns.color_palette('viridis', n_colors=len(avg_price_room_type_df)))
plt.title('Proportion of Average Price by Room Type')
plt.show()

# %% [markdown]
# Observation:
# The average price is highest for renting an entire home or apartment, followed by a private room, with shared rooms having the lowest average price.

# %% [markdown]
# ## c. Number of listings based on room-type

# %%
count_room_type = df.groupby('room_type').size().sort_values(ascending=False).reset_index(name='count')
count_room_type_df = pd.DataFrame(count_room_type)
count_room_type_df
# Out:
#          room_type  count
# 0  Entire home/apt  25409
# 1     Private room  22326
# 2      Shared room   1160

# %%
plt.figure(figsize=(6, 4))
fig = sns.barplot(x = "room_type", y = "count", data = count_room_type_df, palette='viridis', gap = 0.5)
plt.xlabel('Room Type')
plt.ylabel('Count of listings')
plt.title('Number of listings based on Room Type')
plt.show(fig)

# %% [markdown]
# Observation:
# There are far fewer shared room listings compared to private rooms and entire homes/apartments. Entire homes/apartments have the highest number of listings.

# %% [markdown]
# ## d. Top 10 neighbourhoods in each borough

# %%
borough_neighborhood_roomtype = df.groupby(['borough', 'neighbourhood', 'room_type']).size().reset_index(name='count')
borough_neighborhood_roomtype.head()
# Out:
#   borough neighbourhood        room_type  count
# 0   Bronx      Allerton  Entire home/apt     16
# 1   Bronx      Allerton     Private room     26
# 2   Bronx    Baychester  Entire home/apt      3
# 3   Bronx    Baychester     Private room      4
# 4   Bronx       Belmont  Entire home/apt      3

# %%
detailted_listing_availability = borough_neighborhood_roomtype.groupby(['borough', 'neighbourhood'])['count'].sum().reset_index()
detailted_listing_availability.head()
# Out:
#   borough neighbourhood  count
# 0   Bronx      Allerton     42
# 1   Bronx    Baychester      7
# 2   Bronx       Belmont     24
# 3   Bronx     Bronxdale     19
# 4   Bronx   Castle Hill      9

# %%
top_neighborhoods = (detailted_listing_availability.sort_values(['borough', 'count'], ascending=[True, False])
                    .groupby('borough').head(10).reset_index(drop=True))
top_neighborhoods.head()
# Out:
#   borough neighbourhood  count
# 0   Bronx   Kingsbridge     70
# 1   Bronx       Fordham     63
# 2   Bronx      Longwood     62
# 3   Bronx    Mott Haven     60
# 4   Bronx     Concourse     50

# %%
plt.figure(figsize=(10,8))
fig = sns.barplot(x = "count", y = "neighbourhood" , hue = 'borough', data = top_neighborhoods, palette = "Paired")
plt.xlabel("Count of listings")
plt.ylabel("Top Neighbourhoods")   
plt.title(" Number of listings available in top 10 neighbourhoods in each borough")
plt.yticks(fontsize=8)
plt.show(fig)

# %% [markdown]
# ## e. Room-type available in each borough

# %%
count_room_type_borough = df.groupby(['borough', 'room_type'])['room_type'].count().reset_index(name='count')
count_room_type_borough_df = pd.DataFrame(count_room_type_borough)
count_room_type_borough_df
# Out:
#           borough        room_type  count
# 0           Bronx  Entire home/apt    379
# 1           Bronx     Private room    652
# 2           Bronx      Shared room     60
# 3        Brooklyn  Entire home/apt   9559
# 4        Brooklyn     Private room  10132
# 5        Brooklyn      Shared room    413
# 6       Manhattan  Entire home/apt  13199
# 7       Manhattan     Private room   7982
# 8       Manhattan      Shared room    480
# 9          Queens  Entire home/apt   2096
# 10         Queens     Private room   3372
# 11         Queens      Shared room    198
# 12  Staten Island  Entire home/apt    176
# 13  Staten Island     Private room    188
# 14  Staten Island      Shared room      9

# %%
fig = sns.barplot(x = "borough", y = "count" , hue = 'room_type', data = count_room_type_borough_df, palette = "cubehelix")
plt.xlabel("Borough - room type")
plt.ylabel("Count of listings")   
plt.title(" Number of listings available in each borough for different room types")
plt.show(fig)

# %% [markdown]
# Observation:
# Manhattan has the highest number of "entire home/apt" listings, followed by Brooklyn, which has more "private room" listings. Similarly, Queens and the Bronx show a similar trend, but Staten Island has an almost equal number of both room types.

# %% [markdown]
# ## f. Average price of listing in each borough based on room-type

# %%
avg_price_room_type_borough = df.groupby(['borough', 'room_type'])['price_in_dollars'].mean().reset_index(name='avg_price_in_dollars')
avg_price_room_type_borough_df = pd.DataFrame(avg_price_room_type_borough)
avg_price_room_type_borough_df
# Out:
#           borough        room_type  avg_price_in_dollars
# 0           Bronx  Entire home/apt            127.506596
# 1           Bronx     Private room             66.788344
# 2           Bronx      Shared room             59.800000
# 3        Brooklyn  Entire home/apt            178.327545
# 4        Brooklyn     Private room             76.500099
# 5        Brooklyn      Shared room             50.527845
# 6       Manhattan  Entire home/apt            249.239109
# 7       Manhattan     Private room            116.776622
# 8       Manhattan      Shared room             88.977083
# 9          Queens  Entire home/apt            147.050573
# 10         Queens     Private room             71.762456
# 11         Queens      Shared room             69.020202
# 12  Staten Island  Entire home/apt            173.846591
# 13  Staten Island     Private room             62.292553
# 14  Staten Island      Shared room             57.444444

# %%
fig = sns.barplot(x = "borough", y = "avg_price_in_dollars" , hue = 'room_type', data = avg_price_room_type_borough_df, palette = "Paired")
plt.xlabel("Borough wise room type")
plt.ylabel("Average price")   
plt.title("Average price of listing in each borough based on room-type")
plt.show(fig)

# %% [markdown]
# Observation:
# The average price for listings across all boroughs follows a similar trend based on room type. The average price for an entire home/apartment is highest in Manhattan, followed by nearly identical prices in Brooklyn and Staten Island. There is little difference in the average price for renting a private room or shared room in Queens and Staten Island.

# %% [markdown]
# ## g. Top 10 host with most number of reviews

# %%
host_id_max_reviews = df.groupby(['host_id'])['number_of_reviews'].agg('max').sort_values(ascending=False)
host_id_max_reviews.head(10)
# Out:
# host_id
# 47621202    629
# 4734398     607
# 37312959    543
# 2369681     540
# 26432133    510
# 12949460    488
# 792159      480
# 2680820     474
# 42273       467
# 23591164    466
# Name: number_of_reviews, dtype: int64

# %%
host_id_max_reviews_df = pd.DataFrame(host_id_max_reviews.head(10))
host_id_max_reviews_df
# Out:
#           number_of_reviews
# host_id
# 47621202                629
# 4734398                 607
# 37312959                543
# 2369681                 540
# 26432133                510
# 12949460                488
# 792159                  480
# 2680820                 474
# 42273                   467
# 23591164                466

# %%
fig = sns.barplot(x = "host_id", y = "number_of_reviews", data = host_id_max_reviews_df, palette = "magma" )
plt.xlabel("Host id's")
plt.ylabel("Number of reviews") 
plt.title("Host with highest number of reviews")
fig.set_xticklabels(fig.get_xticklabels(), rotation=45)
plt.show(fig)

# %% [markdown]
# ## h. Average price based on borough

# %%
avg_price_borough = df.groupby('borough')['price_in_dollars'].mean().sort_values(ascending=False).reset_index()
avg_price_borough_df = pd.DataFrame(avg_price_borough)
avg_price_borough_df
# Out:
#          borough  price_in_dollars
# 0      Manhattan        196.875814
# 1       Brooklyn        124.383207
# 2  Staten Island        114.812332
# 3         Queens         99.517649
# 4          Bronx         87.496792

# %%
plt.figure(figsize=(6, 6))
plt.pie(avg_price_borough_df['price_in_dollars'], labels=avg_price_borough_df['borough'], autopct='%1.0f%%', colors=sns.color_palette('viridis', len(avg_price_borough_df)))
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Proportion of Average Price by Borough')
plt.show()

# %% [markdown]
# ## i. Number of listings in each borough

# %%
df['borough'].value_counts()
# Out:
# borough
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
fig = sns.countplot(x='borough', data=df, palette="Set2", gap = 0.5)
plt.xlabel('borough')
plt.ylabel('Count of listings')
plt.title('Number of Listings in Each Borough')
plt.show(fig)

# %% [markdown]
# Observation:
# Manhattan has the highest number of listings, nearly three times the number in Queens, followed by Brooklyn.

# %% [markdown]
# ## j. Number of neighbourhood's in each borough

# %%
neighborhood_count = df.groupby('borough')['neighbourhood'].nunique().reset_index()
neighborhood_count_df = pd.DataFrame(neighborhood_count)
neighborhood_count_df
# Out:
#          borough  neighbourhood
# 0          Bronx             48
# 1       Brooklyn             47
# 2      Manhattan             32
# 3         Queens             51
# 4  Staten Island             43

# %%
plt.figure(figsize=(8, 6))
fig = sns.barplot(x='borough', y='neighbourhood', data=neighborhood_count_df, palette='cubehelix', gap = 0.5)
for p in fig.patches:
    fig.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.xlabel('Borough')
plt.ylabel('Number of neighborhoods')
plt.title('Number of neighborhoods in each borough')
plt.show(fig)

# %% [markdown]
# Observation:
# Queens has the most neighborhoods, followed by the Bronx and Brooklyn, which have nearly the same number of neighborhoods.

# %% [markdown]
# ## k. Minimum nights stay Vs price

# %%
min_nights_room_type = df.groupby(['room_type'])['minimum_nights'].mean()
min_nights_room_type
# Out:
# room_type
# Entire home/apt    8.506907
# Private room       5.377900
# Shared room        6.475000
# Name: minimum_nights, dtype: float64

# %% [markdown]
# ## l. Lisiting availability based on boroughs

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data = df, x='longitude', y='latitude', hue='borough')
plt.show()

# %% [markdown]
# ## m. Listings with highest number of reviews-borough-roomtype

# %%
top_reviewed_listings = df.nlargest(20,'number_of_reviews')
top_reviewed_listings.head()
# Out:
#         host_id    borough neighbourhood  latitude  longitude     room_type  \
# 11759  47621202     Queens       Jamaica  40.66730  -73.76831  Private room
# 2031    4734398  Manhattan        Harlem  40.82085  -73.94025  Private room
# 2030    4734398  Manhattan        Harlem  40.82124  -73.93838  Private room
# 2015    4734398  Manhattan        Harlem  40.82264  -73.94041  Private room
# 13495  47621202     Queens       Jamaica  40.66939  -73.76975  Private room
#
#        price_in_dollars  minimum_nights  number_of_reviews last_review  \
# 11759                47               1                629  2019-07-05
# 2031                 49               1                607  2019-06-21
# 2030                 49               1                597  2019-06-23
# 2015                 49               1                594  2019-06-15
# 13495                47               1                576  2019-06-27
#
#        reviews_per_month  host_listings_count  availability_365
# ...

# %%
top_reviewed_listings_df = pd.DataFrame(top_reviewed_listings)
top_reviewed_listings_df.head()
# Out:
#         host_id    borough neighbourhood  latitude  longitude     room_type  \
# 11759  47621202     Queens       Jamaica  40.66730  -73.76831  Private room
# 2031    4734398  Manhattan        Harlem  40.82085  -73.94025  Private room
# 2030    4734398  Manhattan        Harlem  40.82124  -73.93838  Private room
# 2015    4734398  Manhattan        Harlem  40.82264  -73.94041  Private room
# 13495  47621202     Queens       Jamaica  40.66939  -73.76975  Private room
#
#        price_in_dollars  minimum_nights  number_of_reviews last_review  \
# 11759                47               1                629  2019-07-05
# 2031                 49               1                607  2019-06-21
# 2030                 49               1                597  2019-06-23
# 2015                 49               1                594  2019-06-15
# 13495                47               1                576  2019-06-27
#
#        reviews_per_month  host_listings_count  availability_365
# ...

# %%
fig = sns.barplot(x = "borough", y = "number_of_reviews", hue = "room_type", data = top_reviewed_listings_df, palette = "mako", gap = 0.4)
plt.xlabel("Borough")
plt.ylabel("Number of reviews") 
plt.title("Listings with highest number of reviews")
plt.figure(figsize=(8, 6))
fig.set_xticklabels(fig.get_xticklabels(), rotation=45)
plt.show(fig)

# %% [markdown]
# Observation:
# Manhattan listings has the highest number of reviews followed by Queens and Brooklyn.

# %% [markdown]
# ## n. Most popular neighbourhood for listings

# %%
popular_listings = df.groupby(['neighbourhood'])['host_id'].count().sort_values(ascending=False)
popular_listings.head(15)
# Out:
# neighbourhood
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
# Hell's Kitchen        1958
# East Village          1853
# Upper East Side       1798
# Crown Heights         1564
# Midtown               1545
# East Harlem           1117
# Greenpoint            1115
# Chelsea               1113
# Lower East Side        911
# Astoria                900
# Name: host_id, dtype: int64

# %%
popular_listings_df = pd.DataFrame(popular_listings.head(15))
popular_listings_df.reset_index(inplace = True)
popular_listings_df
# Out:
#          neighbourhood  host_id
# 0         Williamsburg     3920
# 1   Bedford-Stuyvesant     3714
# 2               Harlem     2658
# 3             Bushwick     2465
# 4      Upper West Side     1971
# 5       Hell's Kitchen     1958
# 6         East Village     1853
# 7      Upper East Side     1798
# 8        Crown Heights     1564
# 9              Midtown     1545
# 10         East Harlem     1117
# 11          Greenpoint     1115
# 12             Chelsea     1113
# 13     Lower East Side      911
# 14             Astoria      900

# %%
fig = sns.barplot(x = "host_id", y = "neighbourhood", data = popular_listings_df, palette = "viridis")
plt.xlabel("Number of guests who host")
plt.ylabel("Neighbourhood area")   
plt.title("Most popular neighbourhood")
plt.show(fig)

# %% [markdown]
# Observation:
# Williamsburg is the most popular neighborhood with the highest number of listings, followed by Bedford-Stuyvesant. Harlem and Bushwick rank third and fourth, while the Upper West Side and Hell's Kitchen, in fifth and sixth place, have nearly the same number of listings.

# %% [markdown]
# ## o. Borough wise price distribution

# %%
borough_price = df[df["price_in_dollars"] < 500]
borough_price_df = pd.DataFrame(borough_price)
borough_price_df.head(2)
# Out:
#    host_id    borough neighbourhood  latitude  longitude        room_type  \
# 0     2787   Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1     2845  Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price_in_dollars  minimum_nights  number_of_reviews last_review  \
# 0               149               1                  9  2018-10-19
# 1               225               1                 45  2019-05-21
#
#    reviews_per_month  host_listings_count  availability_365
# 0                  0                    6               365
# 1                  0                    2               355

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x='borough', y='price_in_dollars', data=borough_price_df, palette="Set2")
plt.xlabel('Neighbourhood')
plt.ylabel('price_in_dollars')
plt.title('borough wise price distribution')
# Out:
# Text(0.5, 1.0, 'borough wise price distribution')

# %% [markdown]
# ## p. price based on minimum nights stay for each borough

# %%
plt.figure(figsize=(5,5))
fig = sns.scatterplot(x='minimum_nights',y='price_in_dollars',data=df, hue = "borough", style = "borough", palette = "hls")
plt.xlabel('Minimum nights stay')
plt.ylabel('price_in_dollars')
plt.title('price based on minimum nights stay and borough')
plt.show(fig)

# %% [markdown]
# Observation:
# Manhattan listings charge the most, followed by Brooklyn, with the Bronx having the lowest prices.

# %% [markdown]
# ## q. Availability_365 based on borough

# %%
plt.figure(figsize=(8,6))
fig = sns.scatterplot(x='latitude',y='longitude',data = df, hue = "availability_365", palette = "viridis")
plt.title('availability_365 for each borough')
plt.show(fig)

# %% [markdown]
# ## 9. checking correlation

# %%
df_corr = df.select_dtypes(include=['number'])
df_corr.head()
# Out:
#    host_id  latitude  longitude  price_in_dollars  minimum_nights  \
# 0     2787  40.64749  -73.97237               149               1
# 1     2845  40.75362  -73.98377               225               1
# 2     4632  40.80902  -73.94190               150               3
# 3     4869  40.68514  -73.95976                89               1
# 4     7192  40.79851  -73.94399                80              10
#
#    number_of_reviews  reviews_per_month  host_listings_count  availability_365
# 0                  9                  0                    6               365
# 1                 45                  0                    2               355
# 2                  0                  1                    1               365
# 3                270                  4                    1               194
# 4                  9                  0                    1                 0

# %%
df_corr.corr()
# Out:
#                       host_id  latitude  longitude  price_in_dollars  \
# host_id              1.000000  0.020224   0.127055          0.015309
# latitude             0.020224  1.000000   0.084788          0.033939
# longitude            0.127055  0.084788   1.000000         -0.150019
# price_in_dollars     0.015309  0.033939  -0.150019          1.000000
# minimum_nights      -0.017364  0.024869  -0.062747          0.042799
# number_of_reviews   -0.140106 -0.015389   0.059094         -0.047954
# reviews_per_month    0.251112 -0.008493   0.126068         -0.020532
# host_listings_count  0.154950  0.019517  -0.114713          0.057472
# availability_365     0.203492 -0.010983   0.082731          0.081829
#
#                      minimum_nights  number_of_reviews  reviews_per_month  \
# host_id                   -0.017364          -0.140106           0.251112
# latitude                   0.024869          -0.015389          -0.008493
# ...

# %%
corr = df_corr.corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True)
df_corr.columns
# Out:
# Index(['host_id', 'latitude', 'longitude', 'price_in_dollars',
#        'minimum_nights', 'number_of_reviews', 'reviews_per_month',
#        'host_listings_count', 'availability_365'],
#       dtype='object')

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud
plt.subplots(figsize=(12,8))

wordcloud = WordCloud(
                          background_color='white',
                          width=1000,
                          height=800
                         ).generate(" ".join(df.neighbourhood))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 10. Dropping unnecessary columns

# %%
df.drop(columns = ['host_id', 'latitude', 'longitude', 'last_review'], axis=1, inplace=True)
df.head(2)
# Out:
#      borough neighbourhood        room_type  price_in_dollars  minimum_nights  \
# 0   Brooklyn    Kensington     Private room               149               1
# 1  Manhattan       Midtown  Entire home/apt               225               1
#
#    number_of_reviews  reviews_per_month  host_listings_count  availability_365
# 0                  9                  0                    6               365
# 1                 45                  0                    2               355

# %% [markdown]
# ## 11. Checking range of numerical columns

# %%
for column in df.select_dtypes(include='number').columns:
    min_value = df[column].min()
    max_value = df[column].max()
    print(f" {column} | Min: {min_value} | Max: {max_value}")
# Out:
#  price_in_dollars | Min: 0 | Max: 10000
#  minimum_nights | Min: 1 | Max: 1250
#  number_of_reviews | Min: 0 | Max: 629
#  reviews_per_month | Min: 0 | Max: 58
#  host_listings_count | Min: 1 | Max: 327
#  availability_365 | Min: 0 | Max: 365

# %% [markdown]
# ## 12. checking for outliers

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x=df['price_in_dollars'])
plt.title('Box Plot of Price in Dollars')
plt.xlabel('Price in Dollars')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x=df['minimum_nights'])
plt.title('Box Plot of minimum_nights stay')
plt.xlabel('minimum_nights stay')
plt.show()

# %%
df.head(2)
# Out:
#      borough neighbourhood        room_type  price_in_dollars  minimum_nights  \
# 0   Brooklyn    Kensington     Private room               149               1
# 1  Manhattan       Midtown  Entire home/apt               225               1
#
#    number_of_reviews  reviews_per_month  host_listings_count  availability_365
# 0                  9                  0                    6               365
# 1                 45                  0                    2               355

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x=df['number_of_reviews'])
plt.title('Box Plot of number_of_reviews')
plt.xlabel('number_of_reviews')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x=df['reviews_per_month'])
plt.title('Box Plot of reviews_per_month')
plt.xlabel('reviews_per_month')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x=df['host_listings_count'])
plt.title('Box Plot of host_listings_count')
plt.xlabel('host_listings_count')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x=df['availability_365'])
plt.title('Box Plot of availability_365')
plt.xlabel('availability_365')
plt.show()

# %%
def calculate_bounds(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return lower_bound, upper_bound

results = []
for col in df.select_dtypes(include=['number']).columns:
    lower_bound, upper_bound = calculate_bounds(df[col])
    results.append({
        'Column': col,
        'Lower Bound': lower_bound,
        'Upper Bound': upper_bound
    })

bounds_df = pd.DataFrame(results)

print(bounds_df)
# Out:
#                 Column  Lower Bound  Upper Bound
# 0     price_in_dollars        -90.0        334.0
# 1       minimum_nights         -5.0         11.0
# 2    number_of_reviews        -33.5         58.5
# 3    reviews_per_month         -1.5          2.5
# 4  host_listings_count         -0.5          3.5
# 5     availability_365       -340.5        567.5

# %% [markdown]
# ## 13. Label encoding - categorical columns

# %%
cat_columns = df.select_dtypes(include=['object']).columns
cat_columns
# Out:
# Index(['borough', 'neighbourhood', 'room_type'], dtype='object')

# %%
num_columns = df.select_dtypes(include=['number']).columns
num_columns
# Out:
# Index(['price_in_dollars', 'minimum_nights', 'number_of_reviews',
#        'reviews_per_month', 'host_listings_count', 'availability_365'],
#       dtype='object')

# %%
## encoding categorical columns
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['borough_encoded'] = label_encoder.fit_transform(df['borough'])
df['neighbourhood_encoded'] = label_encoder.fit_transform(df['neighbourhood'])
df['room_type_encoded'] = label_encoder.fit_transform(df['room_type'])

# %%
df.head(2)
# Out:
#      borough neighbourhood        room_type  price_in_dollars  minimum_nights  \
# 0   Brooklyn    Kensington     Private room               149               1
# 1  Manhattan       Midtown  Entire home/apt               225               1
#
#    number_of_reviews  reviews_per_month  host_listings_count  \
# 0                  9                  0                    6
# 1                 45                  0                    2
#
#    availability_365  borough_encoded  neighbourhood_encoded  room_type_encoded
# 0               365                1                    108                  1
# 1               355                2                    127                  0

# %%
df.dtypes
# Out:
# borough                  object
# neighbourhood            object
# room_type                object
# price_in_dollars          int64
# minimum_nights            int64
# number_of_reviews         int64
# reviews_per_month         int32
# host_listings_count       int64
# availability_365          int64
# borough_encoded           int32
# neighbourhood_encoded     int32
# room_type_encoded         int32
# dtype: object

# %% [markdown]
# ## 14. log transformation

# %%
df['price_in_dollars_log'] = np.log(df.price_in_dollars+1)

# %%
df.head(2)
# Out:
#      borough neighbourhood        room_type  price_in_dollars  minimum_nights  \
# 0   Brooklyn    Kensington     Private room               149               1
# 1  Manhattan       Midtown  Entire home/apt               225               1
#
#    number_of_reviews  reviews_per_month  host_listings_count  \
# 0                  9                  0                    6
# 1                 45                  0                    2
#
#    availability_365  borough_encoded  neighbourhood_encoded  \
# 0               365                1                    108
# 1               355                2                    127
#
#    room_type_encoded  price_in_dollars_log
# 0                  1              5.010635
# 1                  0              5.420535

# %% [markdown]
# ## 15. drop unnecessary columns

# %%
df.drop(columns = ['borough', 'neighbourhood', 'room_type', 'price_in_dollars'], axis=1, inplace=True)
df.head(2)
# Out:
#    minimum_nights  number_of_reviews  reviews_per_month  host_listings_count  \
# 0               1                  9                  0                    6
# 1               1                 45                  0                    2
#
#    availability_365  borough_encoded  neighbourhood_encoded  \
# 0               365                1                    108
# 1               355                2                    127
#
#    room_type_encoded  price_in_dollars_log
# 0                  1              5.010635
# 1                  0              5.420535

# %% [markdown]
# ## 16. split data into train and test

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns=['price_in_dollars_log'])  
y = df['price_in_dollars_log'] 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (34226, 8)
# (14669, 8)
# (34226,)
# (14669,)

# %% [markdown]
# ## 17. scaling data using standard scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("Scaled X_train mean:", X_train_scaled.mean(axis=0))
print("Scaled X_train std deviation:", X_train_scaled.std(axis=0))
# Out:
# Scaled X_train mean: [ 2.07603207e-18  3.25937035e-17 -7.36991384e-17  1.16257796e-17
#  -2.88568458e-17  1.51031333e-16 -8.14842587e-17 -9.81963168e-17]
# Scaled X_train std deviation: [1. 1. 1. 1. 1. 1. 1. 1.]

# %% [markdown]
# ## 18. linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
reg=LinearRegression()
reg.fit(X_train,y_train)
y_pred=reg.predict(X_test)
from sklearn.metrics import r2_score
train_score = reg.score(X_train, y_train)
test_score = r2_score(y_test, y_pred)
print(f"Training score (R^2): {train_score}")
print(f"Test score (R^2): {test_score}")
# Out:
# Training score (R^2): 0.4033755222503911
# Test score (R^2): 0.4036841501800065

# %% [markdown]
# ## 19. Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
rf_reg = RandomForestRegressor(n_estimators=100, random_state=42)
rf_reg.fit(X_train_scaled, y_train)
y_pred_rf = rf_reg.predict(X_test_scaled)
train_score_rf = rf_reg.score(X_train_scaled, y_train)
test_score_rf = r2_score(y_test, y_pred_rf)
print(f"Training score (R^2): {train_score_rf}")
print(f"Test score (R^2): {test_score_rf}")
# Out:
# Training score (R^2): 0.8846395782685684
# Test score (R^2): 0.5571554151410529
